# %%
# !git config --global user.name "Rivindu2"
# !git config --global user.email "rivigith@gmail.com"
# username='Rivindu2'
repo='Dl-butterfly-Models'
# !git clone https://{token}@github.com/{username}/{repo}

# %%
from google.colab import drive
drive.mount('/content/drive')


import tensorflow as tf
import numpy as np
from PIL import Image
# Out:
# Mounted at /content/drive

# %%
# !cp mobilenetclassiy.ipynb /content/Dl-butterfly-Models/Rivindumodel/
# Out:
# cp: cannot stat 'mobilenetclassiy.ipynb': No such file or directory

# %%
# %cd {repo}
# Out:
# [Errno 2] No such file or directory: 'Dl-butterfly-Models'
# /content/Dl-butterfly-Models

# %%
# %ls
# Out:
# Avishkamodel/  Nirashamodel/  Nirojanmodel/  Rivindumodel/
